# %% [markdown]
# # Lesson 4: Persistence and Streaming

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults

# %%
tool = TavilySearchResults(max_results=2)

# %%
class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], operator.add]

# %%
from langgraph.checkpoint.sqlite import SqliteSaver

memory = SqliteSaver.from_conn_string(":memory:")

# %%
class Agent:
    def __init__(self, model, tools, checkpointer, system=""):
        self.system = system
        graph = StateGraph(AgentState)
        graph.add_node("llm", self.call_openai)
        graph.add_node("action", self.take_action)
        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})
        graph.add_edge("action", "llm")
        graph.set_entry_point("llm")
        self.graph = graph.compile(checkpointer=checkpointer)
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_openai(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling: {t}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Back to the model!")
        return {'messages': results}

# %%
prompt = """You are a smart research assistant. Use the search engine to look up information. \
You are allowed to make multiple calls (either together or in sequence). \
Only look up information when you are sure of what you want. \
If you need to look up some information before asking a follow up question, you are allowed to do that!
"""
model = ChatOpenAI(model="gpt-4o")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="What is the weather in sf?")]

# %%
thread = {"configurable": {"thread_id": "1"}}

# %%
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v['messages'])
# Out:
# [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_bmfLa92f6oAIKN9KvXtqbKDz', 'function': {'arguments': '{"query":"current weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 151, 'total_tokens': 173, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_831e067d82', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-552da379-3f86-4d40-bcff-1c725c642beb-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_bmfLa92f6oAIKN9KvXtqbKDz'}])]
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_bmfLa92f6oAIKN9KvXtqbKDz'}
# Back to the model!
# [ToolMessage(content='[{\'url\': \'https://www.accuweather.com/en/us/san-francisco/94103/june-weather/347629\', \'content\': \'# San Francisco, CA\\n\\nSan Francisco\\n\\nCalifornia\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Monthly\\n\\n## June\\n\\n## 2026\\n\\n## 10-Day\\n\\n## Temperature Graph\\n\\n## June Weather in San Francisco\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### July 2026\\n\\n### August 2026\\n\\n### September 2026\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News\\n\\n### Video\\n\\n### Winter Center\\n\\nTop Stories\\n\\nWeather Forecasts\\n\\nExtreme heat to shift west into mid-July prior to return of monsoon [...] 7 hours ago\\n\\nWeather News\\n\\nAmerica 250 events are being canceled, reshaped as heat dome grips US\\n\\n2 days ago\\n\\nSevere Weather\\n\\nStorms, downpours to persist into new week across central, eastern US\\n\\n10 hours ago\\n\\nLive: World Cup 2026 weather updates\\n\\nLATEST ENTRY\\n\\nMexico City match to kick off as planned Sunday despite storms\\n\\n17 hours ago\\n\\nHealth\\n\\nCDC: 125 ill in Princess cruise ship norovirus outbreak\\n\\n2 days ago\\n\\nFeatured Stories\\n\\nWeather News\\n\\nTexas Hill Country marks 1 year since deadly July 4 flood\\n\\n2 days ago\\n\\nWeather News\\n\\nWhat is the most American animal?\\n\\n3 days ago\\n\\nWeather News\\n\\nChicks fly from nest of famous California eagles Jackie and Shadow\\n\\n5 days ago\\n\\nAstronomy\\n\\nA viral sunset and dueling meteor showers are coming in July\\n\\n5 days ago\\n\\nRecreation [...] 5 days ago\\n\\nRecreation\\n\\nGirl survives rabid bat attack after receiving lifesaving treatment\\n\\n3 days ago\\n\\n## Weather Near San Francisco:\\n\\n...\\n\\n...\\n\\n...\'}, {\'url\': \'https://forecast.weather.gov/MapClick.php?lat=37.7771&lon=-122.4196\', \'content\': "National Oceanic and Atmospheric Administration\\nNational Weather Service\\nUnited States Department of Commerce\\n\\nNWS\\n\\nAll NOAA\\n\\nYour local forecast office is\\n\\n### San Francisco Bay Area/Monterey, CA\\n\\n# Super Typhoon Bavi to Impact Guam and the Mariana Islands; Excessive Rainfall and Flooding Threat in the Mid-Atlantic\\n\\nCatastrophic Super Typhoon Bavi\'s eyewall has reached Rota and is expected to bring dangerous winds, heavy rainfall and storm surge to Guam, Rota, Tinian and Saipan. A Typhoon Warning remains in effect. Heavy to excessive rainfall will continue to bring a flooding threat from coastal Mid-Atlantic to southern New England through Monday.\\nRead More >\\n\\n### Hazardous Weather Conditions\\n\\n## SAN FRANCISCO DOWNTOWN (SFOC1)\\n\\nNA\\n\\n57°F\\n\\n14°C [...] High: 64 °F\\n\\nDecreasing  \\nClouds\\n\\nTuesday Night\\n\\nTuesday Night: Partly cloudy, with a low around 54. West wind 10 to 17 mph, with gusts as high as 26 mph. \\n\\nTuesday Night: Partly cloudy, with a low around 54. West wind 10 to 17 mph, with gusts as high as 26 mph. \\n\\nLow: 54 °F\\n\\nPartly Cloudy\\n\\nWednesday\\n\\nWednesday: Mostly sunny, with a high near 68.\\n\\nWednesday: Mostly sunny, with a high near 68.\\n\\nHigh: 68 °F\\n\\nMostly Sunny\\n\\nWednesday Night\\n\\nWednesday Night: Mostly clear, with a low around 56.\\n\\nWednesday Night: Mostly clear, with a low around 56.\\n\\nLow: 56 °F\\n\\nMostly Clear\\n\\nThursday\\n\\nThursday: Mostly sunny, with a high near 68.\\n\\nThursday: Mostly sunny, with a high near 68.\\n\\nHigh: 68 °F\\n\\nMostly Sunny\\n\\nThursday Night\\n\\nThursday Night: Mostly clear, with a low around 56. [...] ## SAN FRANCISCO DOWNTOWN (SFOC1)\\n\\nNA ...
# [AIMessage(content='The current weather in San Francisco is mostly cloudy with a temperature of approximately 57°F (14°C). The forecast for tonight is mostly cloudy with a low around 55°F (13°C) and a west-southwest wind at 6 to 8 mph. Tomorrow, it is expected to be cloudy through mid-morning, then gradually clearing, with a high near 66°F (19°C) and west winds of 6 to 14 mph, with gusts up to 18 mph.', response_metadata={'token_usage': {'completion_tokens': 103, 'prompt_tokens': 1414, 'total_tokens': 1517, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_683410201e', 'finish_reason': 'stop', 'logprobs': None}, id='run-14660e6f-2368-4439-8063-4f51e6fae2f8-0')]

# %%
messages = [HumanMessage(content="What about in la?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_2fgTc1JzdQImvVaAYus8VgGB', 'function': {'arguments': '{"query":"current weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 1529, 'total_tokens': 1551, 'prompt_tokens_details': {'cached_tokens': 1408, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_683410201e', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7b764e1c-c0ed-417a-86e7-0b4512a6117e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_2fgTc1JzdQImvVaAYus8VgGB'}])]}
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Los Angeles'}, 'id': 'call_2fgTc1JzdQImvVaAYus8VgGB'}
# Back to the model!
# {'messages': [ToolMessage(content="[{'url': 'https://www.accuweather.com/en/us/los-angeles/90012/july-weather/347625', 'content': '### Winter Center\\n\\n## Monthly\\n\\n## July\\n\\n## 2026\\n\\n## 10-Day\\n\\nPlenty of sunshine\\nPartly sunny\\nPartly sunny\\nMostly sunny\\nPlenty of sun\\nHazy sun\\nTimes of clouds and sun\\nMostly sunny\\nMostly sunny\\nAn a.m. shower; partly sunny\\nPartly sunny and less humid\\nSome sun\\nPlenty of sun\\nA thick cloud cover\\nConsiderable cloudiness\\nPlenty of sunshine\\nMostly sunny\\nMostly sunny\\nMostly sunny\\nIncreasing cloudiness\\nMostly cloudy and warm\\nDecreasing clouds\\nMostly sunny\\nPlenty of sun\\nMostly sunny\\nMostly cloudy\\nTimes of clouds and sun\\nSunny to partly cloudy\\n\\n## Temperature Graph\\n\\n## July Weather in Los Angeles\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### August 2026\\n\\n### September 2026\\n\\n### October 2026\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News [...] ### Severe Weather\\n\\n### Radar & Maps\\n\\n### News\\n\\n### Video\\n\\n### Winter Center\\n\\nTop Stories\\n\\nWeather Forecasts\\n\\nExtreme heat to shift west into mid-July prior to return of monsoon\\n\\n7 hours ago\\n\\nWeather News\\n\\nAmerica 250 events are being canceled, reshaped as heat dome grips US\\n\\n2 days ago\\n\\nSevere Weather\\n\\nStorms, downpours to persist into new week across central, eastern US\\n\\n10 hours ago\\n\\nLive: World Cup 2026 weather updates\\n\\nLATEST ENTRY\\n\\nMexico City match to kick off as planned Sunday despite storms\\n\\n17 hours ago\\n\\nHealth\\n\\nCDC: 125 ill in Princess cruise ship norovirus outbreak\\n\\n2 days ago\\n\\nFeatured Stories\\n\\nWeather News\\n\\nTexas Hill Country marks 1 year since deadly July 4 flood\\n\\n2 days ago\\n\\nWeather News\\n\\nWhat is the most American animal?\\n\\n3 days ago\\n\\nWeather News [...] # Los Angeles, CA\\n\\nLos Angeles\\n\\nCalifornia\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Monthly\\n\\n## July\\n\\n## 2026\\n\\n## 10-Day'}, {'url': 'https://www.accuweather.com/en/us/los-angeles/90012/june-weather/347625', 'content': '# Los Angeles, CA\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Monthly\\n\\n## June\\n\\n## 2026\\n\\n## 10-Day\\n\\n## Temperature Graph\\n\\n## June Weather in Los Angeles\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### July 2026\\n\\n### August 2026\\n\\n### September 2026\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News\\n\\n### Video\\n\\n### Winter Center\\n\\n## Weather Near Los Angeles:'}]", name='tavily_search_results_json', tool_call_id='call_2fgTc1JzdQImvVaAYus8VgGB')]}
# {'messages': [AIMessage(content='The current weather in Los Angeles is characterized by plenty of sunshine. The temperature and additional details are not specified in the available sources, but generally, Los Angeles experiences warm and sunny conditions. If you need more specific weather details such as temperature or wind speed, checking a local weather service or app might provide the latest updates.', response_metadata={'token_usage': {'completion_tokens': 65, 'prompt_tokens': 2402, 'total_tokens': 2467, 'prompt_tokens_details': {'cached_tokens': 1536, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_683410201e', 'finish_reason': 'stop', 'logprobs': None}, id='run-aff4e910-5ae4-48fa-a8cb-c32a8ab1bbd4-0')]}

# %%
messages = [HumanMessage(content="Which one is warmer?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content="Based on the current weather data available, Los Angeles is generally warmer than San Francisco. San Francisco has a temperature of about 57°F (14°C) with mostly cloudy conditions, while Los Angeles is experiencing plenty of sunshine, which typically indicates warmer temperatures. However, specific temperature data for Los Angeles isn't available from the sources I accessed, but it is generally known to be warmer than San Francisco.", response_metadata={'token_usage': {'completion_tokens': 80, 'prompt_tokens': 2479, 'total_tokens': 2559, 'prompt_tokens_details': {'cached_tokens': 2432, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_683410201e', 'finish_reason': 'stop', 'logprobs': None}, id='run-919cbd8b-a320-4bc7-94b6-e8c163c02bda-0')]}

# %%
messages = [HumanMessage(content="Which one is warmer?")]
thread = {"configurable": {"thread_id": "2"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [AIMessage(content="Could you please clarify what you're comparing to determine which is warmer? Are you comparing two specific locations, types of clothing, materials, or something else? Let me know so I can provide the appropriate information.", response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 149, 'total_tokens': 192, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-4o', 'system_fingerprint': 'fp_f9f4fb6dbf', 'finish_reason': 'stop', 'logprobs': None}, id='run-53843c1e-980d-4bd4-a34b-244e88b83ef3-0')]}

# %% [markdown]
# ## Streaming tokens

# %%
from langgraph.checkpoint.aiosqlite import AsyncSqliteSaver

memory = AsyncSqliteSaver.from_conn_string(":memory:")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="What is the weather in SF?")]
thread = {"configurable": {"thread_id": "4"}}
async for event in abot.graph.astream_events({"messages": messages}, thread, version="v1"):
    kind = event["event"]
    if kind == "on_chat_model_stream":
        content = event["data"]["chunk"].content
        if content:
            # Empty content in the context of OpenAI means
            # that the model is asking for a tool to be invoked.
            # So we only print non-empty content
            print(content, end="|")
# Out:
# /usr/local/lib/python3.11/site-packages/langchain_core/_api/beta_decorator.py:87: LangChainBetaWarning: This API is in beta and may change in the future.
#   warn_beta(
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in San Francisco'}, 'id': 'call_GiHnpbt7P6kuX4g2n6imqDXI'}
# Back to the model!
# I| encountered| an| error| while| trying| to| retrieve| the| current| weather| information| for| San| Francisco|.| You| might| want| to| check| a| reliable| weather| website| or| app| for| the| most| up|-to|-date| information|.| If| there's| anything| else| you'd| like| to| know| or| another| way| I| can| assist| you|,| please| let| me| know|!|
