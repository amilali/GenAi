# %% [markdown]
# # Lesson 5: Human in the Loop

# %% [markdown]
# Note: This notebook is running in a later version of langgraph that it was filmed with. The later version has a couple of key additions:
# - Additional state information is stored to memory and displayed when using `get_state()` or `get_state_history()`.
# - State is additionally stored every state transition while previously it was stored at an interrupt or at the end.
# These change the command output slightly, but are a useful addtion to the information available.

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.checkpoint.sqlite import SqliteSaver

memory = SqliteSaver.from_conn_string(":memory:")

# %%
from uuid import uuid4
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, AIMessage

"""
In previous examples we've annotated the `messages` state key
with the default `operator.add` or `+` reducer, which always
appends new messages to the end of the existing messages array.

Now, to support replacing existing messages, we annotate the
`messages` key with a customer reducer function, which replaces
messages with the same `id`, and appends them otherwise.
"""
def reduce_messages(left: list[AnyMessage], right: list[AnyMessage]) -> list[AnyMessage]:
    # assign ids to messages that don't have them
    for message in right:
        if not message.id:
            message.id = str(uuid4())
    # merge the new messages with the existing messages
    merged = left.copy()
    for message in right:
        for i, existing in enumerate(merged):
            # replace any existing messages with the same id
            if existing.id == message.id:
                merged[i] = message
                break
        else:
            # append any new messages to the end
            merged.append(message)
    return merged

class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], reduce_messages]

# %%
tool = TavilySearchResults(max_results=2)

# %% [markdown]
# ## Manual human approval

# %%
class Agent:
    def __init__(self, model, tools, system="", checkpointer=None):
        self.system = system
        graph = StateGraph(AgentState)
        graph.add_node("llm", self.call_openai)
        graph.add_node("action", self.take_action)
        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})
        graph.add_edge("action", "llm")
        graph.set_entry_point("llm")
        self.graph = graph.compile(
            checkpointer=checkpointer,
            interrupt_before=["action"]
        )
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_openai(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        print(state)
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling: {t}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Back to the model!")
        return {'messages': results}

# %%
prompt = """You are a smart research assistant. Use the search engine to look up information. \
You are allowed to make multiple calls (either together or in sequence). \
Only look up information when you are sure of what you want. \
If you need to look up some information before asking a follow up question, you are allowed to do that!
"""
model = ChatOpenAI(model="gpt-3.5-turbo")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="Whats the weather in SF?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in SF?', id='3e854c96-df8d-4930-bb79-9fb0744a1457'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0', 'function': {'arguments': '{"query":"weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 152, 'total_tokens': 174, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ae1f0e43-2b86-456a-8ff9-60d6757d003f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0'}])]}
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0', 'function': {'arguments': '{"query":"weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 152, 'total_tokens': 174, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-ae1f0e43-2b86-456a-8ff9-60d6757d003f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0'}])]}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in SF?', id='3e854c96-df8d-4930-bb79-9fb0744a1457'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-ae1f0e43-2b86-456a-8ff9-60d6757d003f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0'}])]}, next=('action',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179ef7-3d3c-6c11-8001-adc1c972257e'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-ae1f0e43-2b86-456a-8ff9-60d6757d003f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0'}])]}}}, created_at='2026-07-07T10:34:37.260067+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f179ef7-3ba1-69b9-8000-3514d43b4df9'}})

# %%
abot.graph.get_state(thread).next
# Out:
# ('action',)

# %% [markdown]
# ### continue after interrupt

# %%
for event in abot.graph.stream(None, thread):
    for v in event.values():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.accuweather.com/en/us/san-francisco/94103/july-weather/347629\', \'content\': "69°\\n\\n58° 1\\n\\nIncreasing cloudiness\\n\\n67°\\n\\n57°\\n\\n## Temperature Graph\\n\\n°F\\n\\nAvg. Hi\\n\\nAvg. Lo\\n\\nActual Hi\\n\\nActual Lo\\n\\nForecast Hi\\n\\nForecast Lo\\n\\n## July Weather in San Francisco\\n\\nSan Francisco\'s July 2026 forecast shows daily high temperatures ranging from 63° to 71°, with overnight lows between 54° and 58°. The average high for July is 68° with an average low of 56°. AccuWeather\'s monthly forecast extends further ahead than any other source, with day-by-day RealFeel® Temperatures giving a complete picture of how July weather will actually feel in San Francisco. See also: August | September | October.\\n\\nFurther Ahead\\n\\n### August 2026 ### September 2026 ### October 2026\\n\\nAround the Globe\\n\\n### Hurricane Tracker ### Severe Weather ### Radar & Maps ### News ### Video ### Winter Center\\n\\nTop Stories"}, {\'url\': \'https://www.aqi.in/weather/us/united-states/california/san-francisco\', \'content\': "8 PM\\n\\nSunnySunny\\n\\n15°C\\n\\n78%\\n\\n0\\n\\n17.3kmph /  WSW\\n\\nFeels Like IconFeels 15 °C\\n\\nTemperature IconCover 0 %\\n\\nVisibility IconVisibility 10 km\\n\\n9 PM\\n\\nClearClear\\n\\n14°C\\n\\n83%\\n\\n0\\n\\n16.2kmph /  WSW\\n\\nFeels Like IconFeels 13 °C\\n\\nTemperature IconCover 4 %\\n\\nVisibility IconVisibility 10 km\\n\\n10 PM\\n\\nClearClear\\n\\n14°C\\n\\n84%\\n\\n0\\n\\n15.1kmph /  WSW\\n\\nFeels Like IconFeels 13 °C\\n\\nTemperature IconCover 9 %\\n\\nVisibility IconVisibility 10 km\\n\\n11 PM\\n\\nClearClear\\n\\n14°C\\n\\n85%\\n\\n0\\n\\n14kmph /  WSW\\n\\nFeels Like IconFeels 13 °C\\n\\nTemperature IconCover 16 %\\n\\nVisibility IconVisibility 10 km\\n\\nTemp18 °C\\n\\nConditionPartly Cloudy\\n\\nHumidity70 %\\n\\nFeels16 °C\\n\\nCover50 %\\n\\nVisibility16 km\\n\\nWind Speed & Dir.19.4 kmph /  WSW\\n\\nUV0.5\\n\\n## San Francisco 30-Days (July 2026) Weather Forecast\\n\\nSee Hourly\\n\\nSun.Mon.Tue.Wed.Thu.Fri.Sat.\\n\\n1\\n\\nSunny20°11°\\n\\n2 [...] ### JulyWeather Overview\\n\\n| No. of days: |\\n\\n| Sunny | 17 |\\n| Cloudy | 1 |\\n| Rainy | 11 |\\n| Snowy | 0 |\\n\\n#### No. of days:\\n\\nSunny\\n\\nSunny\\n\\n17\\n\\nCloudy\\n\\nCloudy\\n\\n1\\n\\nRainy\\n\\nRainy\\n\\n11\\n\\nSnowy\\n\\nSnowy\\n\\n0\\n\\nThe monthly weather averages in San Francisco consist of 17 sunny days, 1 cloudy days, 11 rainy days, and 0 snowy days.\\n\\n## San Francisco\'s Locations Weather Conditions\\n\\nLocations\\n\\nTemp\\n\\nCondition\\n\\nHumi.\\n\\nUV\\n\\nWind Speed & Direction\\n\\nPotrero Hill\\n\\n18 °C\\n\\npartly cloudyPartly Cloudy\\n\\n70%\\n\\n0.5\\n\\n19.4kmph /  WSW\\n\\nSan Francisco Arkansas Street\\n\\n18 °C\\n\\npartly cloudyPartly Cloudy\\n\\n70%\\n\\n0.5\\n\\n19.4kmph /  WSW\\n\\n## United States\'s Hottest Cities - July 2026\\n\\nHottest\\n\\nColdest\\n\\nRankCityTemperatureWeather ConditionHumidityUVWind Speed & Dir.Follow\\n\\n1.\\n\\nUnited States flagEl Centro, California\\n\\n43 °C\\n\\nsunnySunny [...] 4. Will it rain in San Francisco today?\\n\\nAs of 07:00 PM 05 July 2026, there is a 7% chance of rainfall in San Francisco later today around 2026-07-05 19:00. Current precipitation is 0 mm. Residents are advised to carry an umbrella before heading out.\\n\\n5. What is the monthly weather forecast for San Francisco in July 2026?\\n\\nJuly 2026 in San Francisco is forecast to have 17 sunny days, 11 rainy days, 1 cloudy days, and 0 snowy days. Temperatures for the month range from lows around 11°C to highs of 22°C.\\n\\n6. How does the weather in San Francisco affect air quality?"}]', name='tavily_search_results_json', id='efd62158-920d-4788-88f2-1d8a1fc0bc0e', tool_call_id='call_i7rGhnzgZf5hW3bsDcqdTrH0')]}
# {'messages': [HumanMessage(content='Whats the weather in SF?', id='3e854c96-df8d-4930-bb79-9fb0744a1457'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-ae1f0e43-2b86-456a-8ff9-60d6757d003f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0'}]), ToolMessage(content='[{\'url\': \'https://www.accuweather.com/en/us/san-francisco/94103/july-weather/347629\', \'content\': "69°\\n\\n58° 1\\n\\nIncreasing cloudiness\\n\\n67°\\n\\n57°\\n\\n## Temperature Graph\\n\\n°F\\n\\nAvg. Hi\\n\\nAvg. Lo\\n\\nActual Hi\\n\\nActual Lo\\n\\nForecast Hi\\n\\nForecast Lo\\n\\n## July Weather in San Francisco\\n\\nSan Francisco\'s July 2026 forecast shows daily high temperatures ranging from 63° to 71°, with overnight lows between 54° and 58°. The average high for July is 68° with an average low of 56°. AccuWeather\'s monthly forecast extends further ahead than any other source, with day-by-day RealFeel® Temperatures giving a complete picture of how July weather will actually feel in San Francisco. See also: August | September | October.\\n\\nFurther Ahead\\n\\n### August 2026 ### September 2026 ### October 2026\\n\\nAround the Globe\\n\\n### Hurricane Tracker ### Severe Weather ### Radar & Maps ### News ### Video ### Winter Center\\n\\nTop Stories"}, {\'url\': \'https://www.aqi.in/weather/us/united-states/california/san-francisco\', \'content\': "8 PM\\n\\nSunnySunny\\n\\n15°C\\n\\n78%\\n\\n0\\n\\n17.3kmph /  WSW\\n\\nFeels Like IconFeels 15 °C\\n\\nTemperature IconCover 0 %\\n\\nVisibility IconVisibility 10 km\\n\\n9 PM\\n\\nClearClear\\n\\n14°C\\n\\n83%\\n\\n0\\n\\n16.2kmph /  WSW\\n\\nFeels Like IconFeels 13 °C\\n\\nTemperature IconCover 4 %\\n\\nVisibility IconVisibility 10 km\\n\\n10 PM\\n\\nClearClear\\n\\n14°C\\n\\n84%\\n\\n0\\n\\n15.1kmph /  WSW\\n\\nFeels Like IconFeels 13 °C\\n\\nTemperature IconCover 9 %\\n\\nVisibility IconVisibility 10 km\\n\\n11 PM\\n\\nClearClear\\n\\n14°C\\n\\n85%\\n\\n0\\n\\n14kmph /  WSW\\n\\nFeels Like IconFeels 13 °C\\n\\nTemperature IconCover 16 %\\n\\nVisibility IconVisibility 10 km\\n\\nTemp18 °C\\n\\nConditionPartly Cloudy\\n\\nHumidity70 %\\n\\nFeels16 °C\\n\\nCover50 %\\n\\nVisibility16 km\\n\\nWind Speed & Dir.19.4 kmph /  WSW\\n\\nUV0.5\\n\\n## San Francisco 30-Days (July 2026) Weather Forecast\\n\\nSee Hourly\\n\\nSun.Mon.Tue.Wed.Thu.Fri.Sat.\\n\\n1\\n\\nSunny20°11°\\n\\n2 [...] ### JulyWeather Overview\\n\\n| No. of days: |\\n\\n| Sunny | 17 |\\n| Cloudy | 1 |\\n| Rainy | 11 |\\n| Snowy | 0 |\\n\\n#### No. of days:\\n\\nSunny\\n\\nSunny\\n\\n17\\n\\nCloudy\\n\\nCloudy\\n\\n1\\n\\nRainy\\n\\nRainy\\n\\n11\\n\\nSnowy\\n\\nSnowy\\n\\n0\\n\\nThe monthly weather averages in San Francisco consist of 17 sunny days, 1 cloudy days, 11 rainy days, and 0 snowy days.\\n\\n## San Francisco\'s Locations Weather Conditions\\n\\nLocations\\n\\nTemp\\n\\nCondition\\n\\nHumi.\\n\\nUV\\n\\nWind Speed & Direction\\n\\nPotrero Hill\\n\\n18 °C\\n\\npartly cloudyPartly Cloudy\\n\\n70%\\n\\n0.5\\n\\n19.4kmph /  WSW\\n\\nSan Francisco Arkansas Street\\n\\n18 °C\\n\\npartly cloudyPartly Cloudy\\n\\n70%\\n\\n0.5\\n\\n19.4kmph /  WSW\\n\\n## United States\'s Hottest Cities - July 2026\\n\\nHottest\\n\\nColdest\\n\\nRankCityTemperatureWeather ConditionHumidityUVWind Speed & Dir.Follow\\n\\n1.\\n\\nUnited States flagEl Centro, California\\n\\n43 °C\\n\\n ...
# {'messages': [AIMessage(content='The current weather in San Francisco is partly cloudy with a temperature of 18°C. The humidity is 70%, and the wind speed is 19.4 kmph coming from the west-southwest direction. There is a 7% chance of rainfall later today.', response_metadata={'token_usage': {'completion_tokens': 56, 'prompt_tokens': 1268, 'total_tokens': 1324, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-9541d8c4-7b0c-413a-bd48-053f64c7fa41-0')]}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in SF?', id='3e854c96-df8d-4930-bb79-9fb0744a1457'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in San Francisco"}', 'name': 'tavily_search_results_json'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-ae1f0e43-2b86-456a-8ff9-60d6757d003f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_i7rGhnzgZf5hW3bsDcqdTrH0'}]), ToolMessage(content='[{\'url\': \'https://www.accuweather.com/en/us/san-francisco/94103/july-weather/347629\', \'content\': "69°\\n\\n58° 1\\n\\nIncreasing cloudiness\\n\\n67°\\n\\n57°\\n\\n## Temperature Graph\\n\\n°F\\n\\nAvg. Hi\\n\\nAvg. Lo\\n\\nActual Hi\\n\\nActual Lo\\n\\nForecast Hi\\n\\nForecast Lo\\n\\n## July Weather in San Francisco\\n\\nSan Francisco\'s July 2026 forecast shows daily high temperatures ranging from 63° to 71°, with overnight lows between 54° and 58°. The average high for July is 68° with an average low of 56°. AccuWeather\'s monthly forecast extends further ahead than any other source, with day-by-day RealFeel® Temperatures giving a complete picture of how July weather will actually feel in San Francisco. See also: August | September | October.\\n\\nFurther Ahead\\n\\n### August 2026 ### September 2026 ### October 2026\\n\\nAround the Globe\\n\\n### Hurricane Tracker ### Severe Weather ### Radar & Maps ### News ### Video ### Winter Center\\n\\nTop Stories"}, {\'url\': \'https://www.aqi.in/weather/us/united-states/california/san-francisco\', \'content\': "8 PM\\n\\nSunnySunny\\n\\n15°C\\n\\n78%\\n\\n0\\n\\n17.3kmph /  WSW\\n\\nFeels Like IconFeels 15 °C\\n\\nTemperature IconCover 0 %\\n\\nVisibility IconVisibility 10 km\\n\\n9 PM\\n\\nClearClear\\n\\n14°C\\n\\n83%\\n\\n0\\n\\n16.2kmph /  WSW\\n\\nFeels Like IconFeels 13 °C\\n\\nTemperature IconCover 4 %\\n\\nVisibility IconVisibility 10 km\\n\\n10 PM\\n\\nClearClear\\n\\n14°C\\n\\n84%\\n\\n0\\n\\n15.1kmph /  WSW\\n\\nFeels Like IconFeels 13 °C\\n\\nTemperature IconCover 9 %\\n\\nVisibility IconVisibility 10 km\\n\\n11 PM\\n\\nClearClear\\n\\n14°C\\n\\n85%\\n\\n0\\n\\n14kmph /  WSW\\n\\nFeels Like IconFeels 13 °C\\n\\nTemperature IconCover 16 %\\n\\nVisibility IconVisibility 10 km\\n\\nTemp18 °C\\n\\nConditionPartly Cloudy\\n\\nHumidity70 %\\n\\nFeels16 °C\\n\\nCover50 %\\n\\nVisibility16 km\\n\\nWind Speed & Dir.19.4 kmph /  WSW\\n\\nUV0.5\\n\\n## San Francisco 30-Days (July 2026) Weather Forecast\\n\\nSee Hourly\\n\\nSun.Mon.Tue.Wed.Thu.Fri.Sat.\\n\\n1\\n\\nSunny20°11°\\n\\n2 [...] ### JulyWeather Overview\\n\\n| No. of days: |\\n\\n| Sunny | 17 |\\n| Cloudy | 1 |\\n| Rainy | 11 |\\n| Snowy | 0 |\\n\\n#### No. of days:\\n\\nSunny\\n\\nSunny\\n\\n17\\n\\nCloudy\\n\\nCloudy\\n\\n1\\n\\nRainy\\n\\nRainy\\n\\n11\\n\\nSnowy\\n\\nSnowy\\n\\n0\\n\\nThe monthly weather averages in San Francisco consist of 17 sunny days, 1 cloudy days, 11 rainy days, and 0 snowy days.\\n\\n## San Francisco\'s Locations Weather Conditions\\n\\nLocations\\n\\nTemp\\n\\nCondition\\n\\nHumi.\\n\\nUV\\n\\nWind Speed & Direction\\n\\nPotrero Hill\\n\\n18 °C\\n\\npartly cloudyPartly Cloudy\\n\\n70%\\n\\n0.5\\n\\n19.4kmph /  WSW\\n\\nSan Francisco Arkansas Street\\n\\n18 °C\\n\\npartly cloudyPartly Cloudy\\n\\n70%\\n\\n0.5\\n\\n19.4kmph /  WSW\\n\\n## United States\'s Hottest Cities - July 2026\\n\\nHottest\\n\\nColdest\\n\\nRankCityTemperatureWeather ConditionHumidityUVWind Speed & Dir.Follow\\n\\n1.\\n\\nUnited States flagEl Centro, Califo ...

# %%
abot.graph.get_state(thread).next
# Out:
# ()

# %%
messages = [HumanMessage("Whats the weather in LA?")]
thread = {"configurable": {"thread_id": "2"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
while abot.graph.get_state(thread).next:
    print("\n", abot.graph.get_state(thread),"\n")
    _input = input("proceed?")
    if _input != "y":
        print("aborting")
        break
    for event in abot.graph.stream(None, thread):
        for v in event.values():
            print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='f9c0fc8a-897c-4c0d-9b35-100986117493'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 152, 'total_tokens': 174, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7ca9ccdf-c640-4d3e-87d1-8a3fb6e8b8e0-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 152, 'total_tokens': 174, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-7ca9ccdf-c640-4d3e-87d1-8a3fb6e8b8e0-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}
#
#  StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='f9c0fc8a-897c-4c0d-9b35-100986117493'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-7ca9ccdf-c640-4d3e-87d1-8a3fb6e8b8e0-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}, next=('action',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179ef7-ee57-64d0-8001-63fb0e833c08'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-7ca9ccdf-c640-4d3e-87d1-8a3fb6e8b8e0-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}}}, created_at='2026-07-07T10:34:55.830725+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179ef7-ed7b-66e7-8000-cdef946d7ae6'}})
#
# proceed?y
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/july-weather/347625\', \'content\': "## Temperature Graph\\n\\n°F\\n\\nAvg. Hi\\n\\nAvg. Lo\\n\\nActual Hi\\n\\nActual Lo\\n\\nForecast Hi\\n\\nForecast Lo\\n\\n## July Weather in Los Angeles\\n\\n Los Angeles\'s July 2026 forecast shows daily high temperatures ranging from 78° to 89°, with overnight lows between 63° and 71°. The average high for July is 85° with an average low of 68°. AccuWeather\'s monthly forecast extends further ahead than any other source, with day-by-day RealFeel® Temperatures giving a complete picture of how July weather will actually feel in Los Angeles. See also: August | September | October. \\n\\n## Further Ahead\\n\\n### August 2026### September 2026### October 2026\\n\\n## Around the Globe\\n\\n### Hurricane Tracker### Severe Weather### Radar & Maps### News### Video### Winter Center\\n\\nTop Stories"}, {\'url\': \'https://world-weather.info/forecast/usa/los_angeles/july-2026\', \'content\': "Weather\\n Archive\\n Widget\\n METAR\\n\\n World\\n United States\\n California\\n Weather in Los Angeles\\n\\n# Weather in Los Angeles in July 2026\\n\\nLos Angeles Weather Forecast for July 2026 is based on long term prognosis and previous years\' statistical data.\\n\\nJanFebMarAprMayJunJulAugSepOctNovDec\\n\\n  \\n\\n## July\\n\\nStart Week On\\n\\n Sun\\n Mon\\n Tue\\n Wed\\n Thu\\n Fri\\n Sat\\n\\n +75°\\n\\n  3.6 mph S 29.6 inHg81 %05:44 AM08:09 PM\\n +77°\\n\\n  +63°\\n\\n  3.4 mph SE 29.6 inHg85 %05:44 AM08:09 PM\\n +81°\\n\\n  +63°\\n\\n  7.2 mph SW 29.6 inHg43 %05:44 AM08:09 PM\\n +82°\\n\\n  +63°\\n\\n  6.9 mph SW 29.6 inHg43 %05:45 AM08:09 PM\\n +82°\\n\\n  +63°\\n\\n  7.2 mph SW 29.6 inHg45 %05:45 AM08:09 PM\\n 6\\n\\n  +82°\\n\\n  +63°\\n\\n  6.9 mph SW 29.6 inHg45 %05:46 AM08:09 PM\\n 7\\n\\n  +82°\\n\\n  +63°\\n\\n  2.9 mph SE 29.6 inHg80 %05:46 AM08:09 PM\\n 8\\n\\n  +84°\\n\\n  +64° [...] ## Wind Directions\\n\\n0%\\n\\n0%\\n\\n0%\\n\\n16.1%\\n\\n12.9%\\n\\n71%\\n\\n0%\\n\\n0%\\n\\nN\\n\\nNE\\n\\nE\\n\\nSE\\n\\nS\\n\\nSW\\n\\nW\\n\\nNW\\n\\nWind direction chart for Los Angeles (daytime), based on July 2026 wind statistics.\\n\\n## Average values in July\\n\\nWind speed\\n\\n7\\n\\nmph\\n\\nPressure\\n\\n30\\n\\ninHg\\n\\nHumidity\\n\\n54\\n\\n%\\n\\nAverage daytime values for July 2026.\\n\\n## Extended weather forecast in Los Angeles\\n\\nHourlyWeek10-Day14-Day30-DayYear\\n\\n## Weather in large and nearby cities\\n\\nWeather in Washington, D.C.+72°\\n\\nSacramento+77°\\n\\nSouth El Monte+66°\\n\\nGardena+66°\\n\\nMarina del Rey+64°\\n\\nWhittier+64°\\n\\nBellflower+68°\\n\\nNorwalk+68°\\n\\nSanta Monica+64°\\n\\nManhattan Beach+64°\\n\\nCompton+68°\\n\\nRosemead+66°\\n\\nGlendale+66°\\n\\nMonterey Park+66°\\n\\nNorth Glendale+66°\\n\\nInglewood+64°\\n\\nBell+68°\\n\\nWest Puente Valley+66°\\n\\nMinimum and maximum  \\nworld\'s temperature today\\n\\nBolivia  \\nVillazón [...] Bolivia  \\nVillazón\\n\\nday\\n:   +61°F\\n\\nnight\\n:   +19°F\\n\\nAfghanistan  \\nKhāsh\\n\\nday\\n:   +118°F\\n\\nnight\\n:   +88°F\\n\\nWeather forecast on your website\\n\\nLos Angeles\\n\\n+68°\\n\\nTemperature units\\n\\n°F°C"}]', name='tavily_search_results_json', id='4ca7aba0-1955-4560-acce-5c93473891c9', tool_call_id='call_6ED1ZQ8nrjYIOY14yqInLPZc')]}
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='f9c0fc8a-897c-4c0d-9b35-100986117493'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-7ca9ccdf-c640-4d3e-87d1-8a3fb6e8b8e0-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}]), ToolMessage(content='[{\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/july-weather/347625\', \'content\': "## Temperature Graph\\n\\n°F\\n\\nAvg. Hi\\n\\nAvg. Lo\\n\\nActual Hi\\n\\nActual Lo\\n\\nForecast Hi\\n\\nForecast Lo\\n\\n## July Weather in Los Angeles\\n\\n Los Angeles\'s July 2026 forecast shows daily high temperatures ranging from 78° to 89°, with overnight lows between 63° and 71°. The average high for July is 85° with an average low of 68°. AccuWeather\'s monthly forecast extends further ahead than any other source, with day-by-day RealFeel® Temperatures giving a complete picture of how July weather will actually feel in Los Angeles. See also: August | September | October. \\n\\n## Further Ahead\\n\\n### August 2026### September 2026### October 2026\\n\\n## Around the Globe\\n\\n### Hurricane Tracker### Severe Weather### Radar & Maps### News### Video### Winter Center\\n\\nTop Stories"}, {\'url\': \'https://world-weather.info/forecast/usa/los_angeles/july-2026\', \'content\': "Weather\\n Archive\\n Widget\\n METAR\\n\\n World\\n United States\\n California\\n Weather in Los Angeles\\n\\n# Weather in Los Angeles in July 2026\\n\\nLos Angeles Weather Forecast for July 2026 is based on long term prognosis and previous years\' statistical data.\\n\\nJanFebMarAprMayJunJulAugSepOctNovDec\\n\\n  \\n\\n## July\\n\\nStart Week On\\n\\n Sun\\n Mon\\n Tue\\n Wed\\n Thu\\n Fri\\n Sat\\n\\n +75°\\n\\n  3.6 mph S 29.6 inHg81 %05:44 AM08:09 PM\\n +77°\\n\\n  +63°\\n\\n  3.4 mph SE 29.6 inHg85 %05:44 AM08:09 PM\\n +81°\\n\\n  +63°\\n\\n  7.2 mph SW 29.6 inHg43 %05:44 AM08:09 PM\\n +82°\\n\\n  +63°\\n\\n  6.9 mph SW 29.6 inHg43 %05:45 AM08:09 PM\\n +82°\\n\\n  +63°\\n\\n  7.2 mph SW 29.6 inHg45 %05:45 AM08:09 PM\\n 6\\n\\n  +82°\\n\\n  +63°\\n\\n  6.9 mph SW 29.6 inHg45 %05:46 AM08:09 PM\\n 7\\n\\n  +82°\\n\\n  +63°\\n\\n  2.9 mph SE 29.6 inHg80 %05:46 AM08:09 PM\\n 8\\n\\n  +84°\\n\\n  +64° [...] ## Wind Directions\\n\\n0%\\n\\n0%\\n\\n0%\\n\\n16.1%\\n\\n12.9%\\n\\n71%\\n\\n0%\\n\\n0%\\n\\nN\\n\\nNE\\n\\nE\\n\\nSE\\n\\nS\\n\\nSW\\n\\nW\\n\\nNW\\n\\nWind direction chart for Los Angeles (daytime), based on July 2026 wind statistics.\\n\\n## Average values in July\\n\\nWind speed\\n\\n7\\n\\nmph\\n\\nPressure\\n\\n30\\n\\ninHg\\n\\nHumidity\\n\\n54\\n\\n%\\n\\nAverage daytime values for July 2026.\\n\\n## Extended weather forecast in Los Angeles\\n\\nHourlyWeek10-Day14-Day30-DayYear\\n\\n## Weather in large and nearby cities\\n\\nWeather in Washington, D.C.+72°\\n\\nSacramento+77°\\n\\nSouth El Monte+66°\\n\\nGardena+66°\\n\\nMarina del Rey+64°\\n\\nWhittier+64°\\n\\nBellflower+68°\\n\\nNorwalk+68°\\n\\nSanta Monica+64°\\n\\nManhattan Beach+64°\\n\\nCompton+68°\\n\\nRosemead+66°\\n\\nGlendale+66°\\n\\nMonterey Park+66°\\n\\nNorth Glendale+66°\\n\\nInglewood+64°\\n\\nBell+68°\\n\\nWest Puente Valley+66°\\n\\nMinimum and maximum  \\nworld\'s temperature today\\n\\nBolivia  \\nVillazón [...] Bolivia  \\nVillazón\\n\\nday\\n:   +61°F\\n\\nnight\\n:   +19°F\\n\\nAfghanistan  \\nKhāsh\\n\\nday\\n:   +118°F\ ...
# {'messages': [AIMessage(content='The weather in Los Angeles for July 2026 shows daily high temperatures ranging from 78°F to 89°F, with overnight lows between 63°F and 71°F. The average high for July is 85°F with an average low of 68°F. The weather forecast indicates a mix of temperatures throughout the month.', response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 1261, 'total_tokens': 1328, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-ebd04459-6cc5-4f11-9d74-fbf59863733e-0')]}

# %% [markdown]
# ## Modify State
# Run until the interrupt and then modify the state.

# %%
messages = [HumanMessage("Whats the weather in LA?")]
thread = {"configurable": {"thread_id": "3"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 152, 'total_tokens': 174, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}
# {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'type': 'function'}]}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 152, 'total_tokens': 174, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}, next=('action',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-2c40-6a2e-8001-b31a069924b2'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}}}, created_at='2026-07-07T10:35:02.322620+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-2ba7-6629-8000-71e36c7636c2'}})

# %%
current_values = abot.graph.get_state(thread)

# %%
current_values.values['messages'][-1]
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])

# %%
current_values.values['messages'][-1].tool_calls
# Out:
# [{'name': 'tavily_search_results_json',
#   'args': {'query': 'weather in Los Angeles'},
#   'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}]

# %%
_id = current_values.values['messages'][-1].tool_calls[0]['id']
current_values.values['messages'][-1].tool_calls = [
    {'name': 'tavily_search_results_json',
  'args': {'query': 'current weather in Louisiana'},
  'id': _id}
]

# %%
abot.graph.update_state(thread, current_values.values)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}
# {'configurable': {'thread_id': '3',
#   'thread_ts': '1f179ef8-c059-6c93-8002-92f662ccc746'}}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}, next=('action',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-c059-6c93-8002-92f662ccc746'}}, metadata={'source': 'update', 'step': 2, 'writes': {'llm': {'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}}}, created_at='2026-07-07T10:35:17.851859+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-2c40-6a2e-8001-b31a069924b2'}})

# %%
for event in abot.graph.stream(None, thread):
    for v in event.values():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.weather2travel.com/louisiana/july\', \'content\': "weather2travel.com - travel deals for your holiday in the sun\\nClick to search\\n\\n# Louisiana weather in July 2026\\n\\nExpect  daytime maximum temperatures of 33°C in Louisiana, USA in July and very high heat and humidity based on long-term weather averages. There are 8 hours of sunshine per day on average with 14 days with some rainfall and typically 174 mm of rainfall in the month. [...] ### How sunny is it in Louisiana in July?\\n\\nThere are normally 8 hours of bright sunshine each day in New Orleans, Louisiana in July - that\'s 60% of daylight hours.\\n\\n### Does it rain in Louisiana in July?\\n\\nThere are usually 14 days with some rain in New Orleans, Louisiana in July and the average monthly rainfall is 174mm.\\n\\n### What is the chance of a hurricane in Louisiana in July?\\n\\nOn average less than 1 day in July in New Orleans, Louisiana is likely to be affected by the passage of one or more tropical storms.\\n\\n## Louisiana July sunrise & sunset times\\n\\nBrowse the sunrise and sunset times for Louisiana in July 2026. Select a month to view Louisiana sunrise and sunset times for the next 12 months. The Louisiana sunrise and sunset times shown below are for New Orleans. [...] JanFebMarAprMayJunJulAugSepOctNovDec\\n\\n| Date | Sunrise times | Sunset times |\\n --- \\n| Wednesday, 1st July 2026 | 05:03 | 19:05 |\\n| Thursday, 16th July 2026 | 05:10 | 19:02 |\\n| Friday, 31st July 2026 | 05:19 | 18:54 |\\n\\n## Be inspired\\n\\nGet your weekly fix of holiday inspiration from some of the world\'s best travel writers plus save on your next trip with the latest exclusive offers\\n\\nWe promise not to share your details\\n\\n## Related posts\\n\\n10 top places with fantastic reasons to visit in 2026\\nTop 10 sunny holiday destinations year round\\nTop winter sun holiday destinations under £500\\n\\n## Popular travel offers\\n\\nMarella Cruises: Top deals on 2026/2027 sailings\\nPriority Pass: up to 20% off annual membership\\nTravelsphere: Top deals on escorted tours worldwide\\n\\n### Explore holiday destinations"}, {\'url\': \'https://www.accuweather.com/en/us/new-orleans/70112/july-weather/348585\', \'content\': \'### Winter Center\\n\\n## Monthly\\n\\n## July\\n\\n## 2026\\n\\n## 10-Day\\n\\nHumid; an afternoon t-storm\\nHumid; a stray p.m. t-storm\\nA t-storm around in the p.m.\\nA p.m. t-storm in spots\\nA t-storm around in the p.m.\\nA morning thunderstorm or two\\nRain and a thunderstorm\\nPeriods of rain\\nA couple of showers\\nMorning rain; mostly cloudy\\nMostly sunny\\nAbundant sunshine\\nPlenty of sunshine\\nMostly sunny\\nDecreasing clouds\\nIncreasing cloudiness\\nAn afternoon thunderstorm\\nA shower and thunderstorm\\nA couple of thunderstorms\\nA shower and thunderstorm\\nA shower and thunderstorm\\nA shower and thunderstorm\\nCloudy\\nShowers around in the morning\\nCloudy with thunderstorms\\nA brief t-storm in the p.m.\\n\\n## Temperature Graph\\n\\n## July Weather in New Orleans\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### August 2026\\n\\n### September 2026 [...] # New Orleans, LA\\n\\nNew Orleans\\n\\nLouisiana\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Monthly\\n\\n## July\\n\\n## 2026\\n\\n## 10-Day [...] Further Ahead\\n\\n### August 2026\\n\\n### September 2026\\n\\n### October 2026\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News\\n\\n### Video\\n\\n### Winter Center\\n\\nTop Stories\\n\\nSevere Weather\\n\\nStorms, downpour ...
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}]), ToolMessage(content='[{\'url\': \'https://www.weather2travel.com/louisiana/july\', \'content\': "weather2travel.com - travel deals for your holiday in the sun\\nClick to search\\n\\n# Louisiana weather in July 2026\\n\\nExpect  daytime maximum temperatures of 33°C in Louisiana, USA in July and very high heat and humidity based on long-term weather averages. There are 8 hours of sunshine per day on average with 14 days with some rainfall and typically 174 mm of rainfall in the month. [...] ### How sunny is it in Louisiana in July?\\n\\nThere are normally 8 hours of bright sunshine each day in New Orleans, Louisiana in July - that\'s 60% of daylight hours.\\n\\n### Does it rain in Louisiana in July?\\n\\nThere are usually 14 days with some rain in New Orleans, Louisiana in July and the average monthly rainfall is 174mm.\\n\\n### What is the chance of a hurricane in Louisiana in July?\\n\\nOn average less than 1 day in July in New Orleans, Louisiana is likely to be affected by the passage of one or more tropical storms.\\n\\n## Louisiana July sunrise & sunset times\\n\\nBrowse the sunrise and sunset times for Louisiana in July 2026. Select a month to view Louisiana sunrise and sunset times for the next 12 months. The Louisiana sunrise and sunset times shown below are for New Orleans. [...] JanFebMarAprMayJunJulAugSepOctNovDec\\n\\n| Date | Sunrise times | Sunset times |\\n --- \\n| Wednesday, 1st July 2026 | 05:03 | 19:05 |\\n| Thursday, 16th July 2026 | 05:10 | 19:02 |\\n| Friday, 31st July 2026 | 05:19 | 18:54 |\\n\\n## Be inspired\\n\\nGet your weekly fix of holiday inspiration from some of the world\'s best travel writers plus save on your next trip with the latest exclusive offers\\n\\nWe promise not to share your details\\n\\n## Related posts\\n\\n10 top places with fantastic reasons to visit in 2026\\nTop 10 sunny holiday destinations year round\\nTop winter sun holiday destinations under £500\\n\\n## Popular travel offers\\n\\nMarella Cruises: Top deals on 2026/2027 sailings\\nPriority Pass: up to 20% off annual membership\\nTravelsphere: Top deals on escorted tours worldwide\\n\\n### Explore holiday destinations"}, {\'url\': \'https://www.accuweather.com/en/us/new-orleans/70112/july-weather/348585\', \'content\': \'### Winter Center\\n\\n## Monthly\\n\\n## July\\n\\n## 2026\\n\\n## 10-Day\\n\\nHumid; an afternoon t-storm\\nHumid; a stray p.m. t-storm\\nA t-storm around in the p.m.\\nA p.m. t-storm in spots\\nA t-storm around in the p.m.\\nA morning thunderstorm or two\\nRain and a thunderstorm\\nPeriods of rain\\nA couple of showers\\nMorning rain; mostly cloudy\\nMostly sunny\\nAbundant sunshine\\nPlenty of sunshine\\nMostly sunny\\nDecreasing clouds\\nIncreasing cloudiness\\nAn afternoon thunderstorm\\nA shower and thunderstorm\\nA couple of thunderstorms\\nA shower and thunderstorm\\nA shower and thunderstorm\\nA shower and thunderstorm\\nCloudy\\nShowers around in the morning\\nCloudy with thunderstorms\\nA brief t-storm in the p.m.\\n\\n## Temperature Graph\\n\\n## July Weather in New Orleans\\ ...
# {'messages': [AIMessage(content='I found information about the weather in Louisiana, particularly in New Orleans. It mentions that in July, the daytime maximum temperatures in Louisiana, USA can reach 33°C with high heat and humidity. There are usually 14 days with some rainfall in July and an average monthly rainfall of 174mm. The website also provides sunrise and sunset times for July in New Orleans.\n\nWould you like me to look up more specific details about the current weather in New Orleans?', response_metadata={'token_usage': {'completion_tokens': 93, 'prompt_tokens': 1312, 'total_tokens': 1405, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-027aaf19-b70d-47f3-b7fc-39e45f5fbf5f-0')]}

# %% [markdown]
# ## Time Travel

# %%
states = []
for state in abot.graph.get_state_history(thread):
    print(state)
    print('--')
    states.append(state)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}]), ToolMessage(content='[{\'url\': \'https://www.weather2travel.com/louisiana/july\', \'content\': "weather2travel.com - travel deals for your holiday in the sun\\nClick to search\\n\\n# Louisiana weather in July 2026\\n\\nExpect  daytime maximum temperatures of 33°C in Louisiana, USA in July and very high heat and humidity based on long-term weather averages. There are 8 hours of sunshine per day on average with 14 days with some rainfall and typically 174 mm of rainfall in the month. [...] ### How sunny is it in Louisiana in July?\\n\\nThere are normally 8 hours of bright sunshine each day in New Orleans, Louisiana in July - that\'s 60% of daylight hours.\\n\\n### Does it rain in Louisiana in July?\\n\\nThere are usually 14 days with some rain in New Orleans, Louisiana in July and the average monthly rainfall is 174mm.\\n\\n### What is the chance of a hurricane in Louisiana in July?\\n\\nOn average less than 1 day in July in New Orleans, Louisiana is likely to be affected by the passage of one or more tropical storms.\\n\\n## Louisiana July sunrise & sunset times\\n\\nBrowse the sunrise and sunset times for Louisiana in July 2026. Select a month to view Louisiana sunrise and sunset times for the next 12 months. The Louisiana sunrise and sunset times shown below are for New Orleans. [...] JanFebMarAprMayJunJulAugSepOctNovDec\\n\\n| Date | Sunrise times | Sunset times |\\n --- \\n| Wednesday, 1st July 2026 | 05:03 | 19:05 |\\n| Thursday, 16th July 2026 | 05:10 | 19:02 |\\n| Friday, 31st July 2026 | 05:19 | 18:54 |\\n\\n## Be inspired\\n\\nGet your weekly fix of holiday inspiration from some of the world\'s best travel writers plus save on your next trip with the latest exclusive offers\\n\\nWe promise not to share your details\\n\\n## Related posts\\n\\n10 top places with fantastic reasons to visit in 2026\\nTop 10 sunny holiday destinations year round\\nTop winter sun holiday destinations under £500\\n\\n## Popular travel offers\\n\\nMarella Cruises: Top deals on 2026/2027 sailings\\nPriority Pass: up to 20% off annual membership\\nTravelsphere: Top deals on escorted tours worldwide\\n\\n### Explore holiday destinations"}, {\'url\': \'https://www.accuweather.com/en/us/new-orleans/70112/july-weather/348585\', \'content\': \'### Winter Center\\n\\n## Monthly\\n\\n## July\\n\\n## 2026\\n\\n## 10-Day\\n\\nHumid; an afternoon t-storm\\nHumid; a stray p.m. t-storm\\nA t-storm around in the p.m.\\nA p.m. t-storm in spots\\nA t-storm around in the p.m.\\nA morning thunderstorm or two\\nRain and a thunderstorm\\nPeriods of rain\\nA couple of showers\\nMorning rain; mostly cloudy\\nMostly sunny\\nAbundant sunshine\\nPlenty of sunshine\\nMostly sunny\\nDecreasing clouds\\nIncreasing cloudiness\\nAn afternoon thunderstorm\\nA shower and thunderstorm\\nA couple of thunderstorms\\nA shower and thunderstorm\\nA shower and thunderstorm\\nA shower and thunderstorm\\nCloudy\\nShowers around in the morning\\nCloudy with thunderstorms\\nA brief t-storm in the p.m.\\n\\n## Temperature Graph\\n\\n## July Wea ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}]), ToolMessage(content='[{\'url\': \'https://www.weather2travel.com/louisiana/july\', \'content\': "weather2travel.com - travel deals for your holiday in the sun\\nClick to search\\n\\n# Louisiana weather in July 2026\\n\\nExpect  daytime maximum temperatures of 33°C in Louisiana, USA in July and very high heat and humidity based on long-term weather averages. There are 8 hours of sunshine per day on average with 14 days with some rainfall and typically 174 mm of rainfall in the month. [...] ### How sunny is it in Louisiana in July?\\n\\nThere are normally 8 hours of bright sunshine each day in New Orleans, Louisiana in July - that\'s 60% of daylight hours.\\n\\n### Does it rain in Louisiana in July?\\n\\nThere are usually 14 days with some rain in New Orleans, Louisiana in July and the average monthly rainfall is 174mm.\\n\\n### What is the chance of a hurricane in Louisiana in July?\\n\\nOn average less than 1 day in July in New Orleans, Louisiana is likely to be affected by the passage of one or more tropical storms.\\n\\n## Louisiana July sunrise & sunset times\\n\\nBrowse the sunrise and sunset times for Louisiana in July 2026. Select a month to view Louisiana sunrise and sunset times for the next 12 months. The Louisiana sunrise and sunset times shown below are for New Orleans. [...] JanFebMarAprMayJunJulAugSepOctNovDec\\n\\n| Date | Sunrise times | Sunset times |\\n --- \\n| Wednesday, 1st July 2026 | 05:03 | 19:05 |\\n| Thursday, 16th July 2026 | 05:10 | 19:02 |\\n| Friday, 31st July 2026 | 05:19 | 18:54 |\\n\\n## Be inspired\\n\\nGet your weekly fix of holiday inspiration from some of the world\'s best travel writers plus save on your next trip with the latest exclusive offers\\n\\nWe promise not to share your details\\n\\n## Related posts\\n\\n10 top places with fantastic reasons to visit in 2026\\nTop 10 sunny holiday destinations year round\\nTop winter sun holiday destinations under £500\\n\\n## Popular travel offers\\n\\nMarella Cruises: Top deals on 2026/2027 sailings\\nPriority Pass: up to 20% off annual membership\\nTravelsphere: Top deals on escorted tours worldwide\\n\\n### Explore holiday destinations"}, {\'url\': \'https://www.accuweather.com/en/us/new-orleans/70112/july-weather/348585\', \'content\': \'### Winter Center\\n\\n## Monthly\\n\\n## July\\n\\n## 2026\\n\\n## 10-Day\\n\\nHumid; an afternoon t-storm\\nHumid; a stray p.m. t-storm\\nA t-storm around in the p.m.\\nA p.m. t-storm in spots\\nA t-storm around in the p.m.\\nA morning thunderstorm or two\\nRain and a thunderstorm\\nPeriods of rain\\nA couple of showers\\nMorning rain; mostly cloudy\\nMostly sunny\\nAbundant sunshine\\nPlenty of sunshine\\nMostly sunny\\nDecreasing clouds\\nIncreasing cloudiness\\nAn afternoon thunderstorm\\nA shower and thunderstorm\\nA couple of thunderstorms\\nA shower and thunderstorm\\nA shower and thunderstorm\\nA shower and thunderstorm\\nCloudy\\nShowers around in the morning\\nCloudy with thunderstorms\\nA brief t-storm in the p.m.\\n\\n## Temperature Graph\\n\\n## July Wea ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}, next=('action',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-c059-6c93-8002-92f662ccc746'}}, metadata={'source': 'update', 'step': 2, 'writes': {'llm': {'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}}}, created_at='2026-07-07T10:35:17.851859+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-2c40-6a2e-8001-b31a069924b2'}})
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}, next=('action',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-2c40-6a2e-8001-b31a069924b2'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}}}, created_at='2026-07-07T10:35:02.322620+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-2ba7-6629-8000-71e36c7636c2'}})
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684')]}, next=('llm',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-2ba7-6629-8000-71e36c7636c2'}}, metadata={'source': 'loop', 'step': 0, 'writes': None}, created_at='2026-07-07T10:35:02.259859+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-2ba4-6f4a-bfff-616fb01c7e54'}})
# --
# StateSnapshot(values={'messages': []}, next=('__start__',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-2ba4-6f4a-bfff-616fb01c7e54'}}, metadata={'source': 'input', 'step': -1, 'writes': {'messages': [HumanMessage(content='Whats the weather in LA?')]}}, created_at='2026-07-07T10:35:02.258865+00:00', parent_config=None)
# --

# %% [markdown]
# To fetch the same state as was filmed, the offset below is changed to `-3` from `-1`. This accounts for the initial state `__start__` and the first state that are now stored to state memory with the latest version of software.

# %%
to_replay = states[-3]

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}, next=('action',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-2c40-6a2e-8001-b31a069924b2'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}}}, created_at='2026-07-07T10:35:02.322620+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-2ba7-6629-8000-71e36c7636c2'}})

# %%
for event in abot.graph.stream(None, to_replay.config):
    for k, v in event.items():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/july-weather/347625\', \'content\': "## Temperature Graph\\n\\n°F\\n\\nAvg. Hi\\n\\nAvg. Lo\\n\\nActual Hi\\n\\nActual Lo\\n\\nForecast Hi\\n\\nForecast Lo\\n\\n## July Weather in Los Angeles\\n\\n Los Angeles\'s July 2026 forecast shows daily high temperatures ranging from 78° to 89°, with overnight lows between 63° and 71°. The average high for July is 85° with an average low of 68°. AccuWeather\'s monthly forecast extends further ahead than any other source, with day-by-day RealFeel® Temperatures giving a complete picture of how July weather will actually feel in Los Angeles. See also: August | September | October. \\n\\n## Further Ahead\\n\\n### August 2026### September 2026### October 2026\\n\\n## Around the Globe\\n\\n### Hurricane Tracker### Severe Weather### Radar & Maps### News### Video### Winter Center\\n\\nTop Stories"}, {\'url\': \'https://world-weather.info/forecast/usa/los_angeles/july-2026\', \'content\': "Weather\\n Archive\\n Widget\\n METAR\\n\\n World\\n United States\\n California\\n Weather in Los Angeles\\n\\n# Weather in Los Angeles in July 2026\\n\\nLos Angeles Weather Forecast for July 2026 is based on long term prognosis and previous years\' statistical data.\\n\\nJanFebMarAprMayJunJulAugSepOctNovDec\\n\\n  \\n\\n## July\\n\\nStart Week On\\n\\n Sun\\n Mon\\n Tue\\n Wed\\n Thu\\n Fri\\n Sat\\n\\n +75°\\n\\n  3.6 mph S 29.6 inHg81 %05:44 AM08:09 PM\\n +77°\\n\\n  +63°\\n\\n  3.4 mph SE 29.6 inHg85 %05:44 AM08:09 PM\\n +81°\\n\\n  +63°\\n\\n  7.2 mph SW 29.6 inHg43 %05:44 AM08:09 PM\\n +82°\\n\\n  +63°\\n\\n  6.9 mph SW 29.6 inHg43 %05:45 AM08:09 PM\\n +82°\\n\\n  +63°\\n\\n  7.2 mph SW 29.6 inHg45 %05:45 AM08:09 PM\\n 6\\n\\n  +82°\\n\\n  +63°\\n\\n  6.9 mph SW 29.6 inHg45 %05:46 AM08:09 PM\\n 7\\n\\n  +82°\\n\\n  +63°\\n\\n  2.9 mph SE 29.6 inHg80 %05:46 AM08:09 PM\\n 8\\n\\n  +84°\\n\\n  +64° [...] ## Wind Directions\\n\\n0%\\n\\n0%\\n\\n0%\\n\\n16.1%\\n\\n12.9%\\n\\n71%\\n\\n0%\\n\\n0%\\n\\nN\\n\\nNE\\n\\nE\\n\\nSE\\n\\nS\\n\\nSW\\n\\nW\\n\\nNW\\n\\nWind direction chart for Los Angeles (daytime), based on July 2026 wind statistics.\\n\\n## Average values in July\\n\\nWind speed\\n\\n7\\n\\nmph\\n\\nPressure\\n\\n30\\n\\ninHg\\n\\nHumidity\\n\\n54\\n\\n%\\n\\nAverage daytime values for July 2026.\\n\\n## Extended weather forecast in Los Angeles\\n\\nHourlyWeek10-Day14-Day30-DayYear\\n\\n## Weather in large and nearby cities\\n\\nWeather in Washington, D.C.+72°\\n\\nSacramento+77°\\n\\nSouth El Monte+66°\\n\\nGardena+66°\\n\\nMarina del Rey+64°\\n\\nWhittier+64°\\n\\nBellflower+68°\\n\\nNorwalk+68°\\n\\nSanta Monica+64°\\n\\nManhattan Beach+64°\\n\\nCompton+68°\\n\\nRosemead+66°\\n\\nGlendale+66°\\n\\nMonterey Park+66°\\n\\nNorth Glendale+66°\\n\\nInglewood+64°\\n\\nBell+68°\\n\\nWest Puente Valley+66°\\n\\nMinimum and maximum  \\nworld\'s temperature today\\n\\nBolivia  \\nVillazón [...] Bolivia  \\nVillazón\\n\\nday\\n:   +61°F\\n\\nnight\\n:   +19°F\\n\\nAfghanistan  \\nKhāsh\\n\\nday\\n:   +118°F\\n\\nnight\\n:   +88°F\\n\\nWeather forecast on your website\\n\\nLos Angeles\\n\\n+68°\\n\\nTemperature units\\n\\n°F°C"}]', name='tavily_search_results_json', id='bf27f3c4-0c39-4288-bb02-e0a8440ae395', tool_call_id='call_6ED1ZQ8nrjYIOY14yqInLPZc')]}
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}]), ToolMessage(content='[{\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/july-weather/347625\', \'content\': "## Temperature Graph\\n\\n°F\\n\\nAvg. Hi\\n\\nAvg. Lo\\n\\nActual Hi\\n\\nActual Lo\\n\\nForecast Hi\\n\\nForecast Lo\\n\\n## July Weather in Los Angeles\\n\\n Los Angeles\'s July 2026 forecast shows daily high temperatures ranging from 78° to 89°, with overnight lows between 63° and 71°. The average high for July is 85° with an average low of 68°. AccuWeather\'s monthly forecast extends further ahead than any other source, with day-by-day RealFeel® Temperatures giving a complete picture of how July weather will actually feel in Los Angeles. See also: August | September | October. \\n\\n## Further Ahead\\n\\n### August 2026### September 2026### October 2026\\n\\n## Around the Globe\\n\\n### Hurricane Tracker### Severe Weather### Radar & Maps### News### Video### Winter Center\\n\\nTop Stories"}, {\'url\': \'https://world-weather.info/forecast/usa/los_angeles/july-2026\', \'content\': "Weather\\n Archive\\n Widget\\n METAR\\n\\n World\\n United States\\n California\\n Weather in Los Angeles\\n\\n# Weather in Los Angeles in July 2026\\n\\nLos Angeles Weather Forecast for July 2026 is based on long term prognosis and previous years\' statistical data.\\n\\nJanFebMarAprMayJunJulAugSepOctNovDec\\n\\n  \\n\\n## July\\n\\nStart Week On\\n\\n Sun\\n Mon\\n Tue\\n Wed\\n Thu\\n Fri\\n Sat\\n\\n +75°\\n\\n  3.6 mph S 29.6 inHg81 %05:44 AM08:09 PM\\n +77°\\n\\n  +63°\\n\\n  3.4 mph SE 29.6 inHg85 %05:44 AM08:09 PM\\n +81°\\n\\n  +63°\\n\\n  7.2 mph SW 29.6 inHg43 %05:44 AM08:09 PM\\n +82°\\n\\n  +63°\\n\\n  6.9 mph SW 29.6 inHg43 %05:45 AM08:09 PM\\n +82°\\n\\n  +63°\\n\\n  7.2 mph SW 29.6 inHg45 %05:45 AM08:09 PM\\n 6\\n\\n  +82°\\n\\n  +63°\\n\\n  6.9 mph SW 29.6 inHg45 %05:46 AM08:09 PM\\n 7\\n\\n  +82°\\n\\n  +63°\\n\\n  2.9 mph SE 29.6 inHg80 %05:46 AM08:09 PM\\n 8\\n\\n  +84°\\n\\n  +64° [...] ## Wind Directions\\n\\n0%\\n\\n0%\\n\\n0%\\n\\n16.1%\\n\\n12.9%\\n\\n71%\\n\\n0%\\n\\n0%\\n\\nN\\n\\nNE\\n\\nE\\n\\nSE\\n\\nS\\n\\nSW\\n\\nW\\n\\nNW\\n\\nWind direction chart for Los Angeles (daytime), based on July 2026 wind statistics.\\n\\n## Average values in July\\n\\nWind speed\\n\\n7\\n\\nmph\\n\\nPressure\\n\\n30\\n\\ninHg\\n\\nHumidity\\n\\n54\\n\\n%\\n\\nAverage daytime values for July 2026.\\n\\n## Extended weather forecast in Los Angeles\\n\\nHourlyWeek10-Day14-Day30-DayYear\\n\\n## Weather in large and nearby cities\\n\\nWeather in Washington, D.C.+72°\\n\\nSacramento+77°\\n\\nSouth El Monte+66°\\n\\nGardena+66°\\n\\nMarina del Rey+64°\\n\\nWhittier+64°\\n\\nBellflower+68°\\n\\nNorwalk+68°\\n\\nSanta Monica+64°\\n\\nManhattan Beach+64°\\n\\nCompton+68°\\n\\nRosemead+66°\\n\\nGlendale+66°\\n\\nMonterey Park+66°\\n\\nNorth Glendale+66°\\n\\nInglewood+64°\\n\\nBell+68°\\n\\nWest Puente Valley+66°\\n\\nMinimum and maximum  \\nworld\'s temperature today\\n\\nBolivia  \\nVillazón [...] Bolivia  \\nVillazón\\n\\nday\\n:   +61°F\\n\\nnight\\n:   +19°F\\n\\nAfghanistan  \\nKhāsh\\n\\nday\\n:   +118°F\ ...
# {'messages': [AIMessage(content='The weather in Los Angeles for July 2026 shows daily high temperatures ranging from 78°F to 89°F, with overnight lows between 63°F and 71°F. The average high for July is 85°F with an average low of 68°F. The weather forecast indicates a mix of temperatures throughout the month.', response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 1261, 'total_tokens': 1328, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-2dd8a56b-766a-45b2-9de7-fa2f3412327f-0')]}

# %% [markdown]
# ## Go back in time and edit

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}, next=('action',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-2c40-6a2e-8001-b31a069924b2'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}}}, created_at='2026-07-07T10:35:02.322620+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-2ba7-6629-8000-71e36c7636c2'}})

# %%
_id = to_replay.values['messages'][-1].tool_calls[0]['id']
to_replay.values['messages'][-1].tool_calls = [{'name': 'tavily_search_results_json',
  'args': {'query': 'current weather in LA, accuweather'},
  'id': _id}]

# %%
branch_state = abot.graph.update_state(to_replay.config, to_replay.values)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}

# %%
for event in abot.graph.stream(None, branch_state):
    for k, v in event.items():
        if k != "__end__":
            print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/july-weather/347625\', \'content\': "### Winter Center\\n\\n## Monthly\\n\\n## July\\n\\n## 2026\\n\\n## 10-Day\\n\\nPartly sunny\\nMostly sunny\\nPlenty of sun\\nMostly sunny\\nMostly cloudy\\nCloudy\\nPlenty of sunshine\\nPlenty of sunlight\\nSunny and warm\\nSunny and warm\\nWarm with sunshine\\nMostly sunny and warm\\nPlenty of sun\\nPlenty of sunshine\\nMostly sunny\\nMostly sunny\\nMostly sunny\\nIncreasing cloudiness\\nMostly cloudy and warm\\nDecreasing clouds\\nMostly sunny\\nPlenty of sun\\nMostly sunny\\nMostly cloudy\\nTimes of clouds and sun\\nSunny to partly cloudy\\n\\n## Temperature Graph\\n\\n## July Weather in Los Angeles\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### August 2026\\n\\n### September 2026\\n\\n### October 2026\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News\\n\\n### Video\\n\\n### Winter Center\\n\\nTop Stories\\n\\nSevere Weather [...] # Los Angeles, CA\\n\\nLos Angeles\\n\\nCalifornia\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Monthly\\n\\n## July\\n\\n## 2026\\n\\n## 10-Day [...] ### Video\\n\\n### Winter Center\\n\\nTop Stories\\n\\nSevere Weather\\n\\nStorms, downpours to persist this week across central, eastern US\\n\\n1 hour ago\\n\\nHurricane\\n\\nAtlantic hurricane season off to a slow start as El Niño strengthens\\n\\n1 hour ago\\n\\nSevere Weather\\n\\nStorms, heat and floods disrupt America’s 250th birthday celebrations\\n\\n15 hours ago\\n\\nWeather Forecasts\\n\\nExtreme heat to shift west into mid-July prior to return of monsoon\\n\\n1 hour ago\\n\\nLive: World Cup 2026 weather updates\\n\\nLATEST ENTRY\\n\\nStorms delay Mexico vs. England showdown in Mexico City\\n\\n20 hours ago\\n\\nFeatured Stories\\n\\nWeather News\\n\\nTexas Hill Country marks 1 year since deadly July 4 flood\\n\\n3 days ago\\n\\nHealth\\n\\nNYC Legionnaires\' disease outbreak jumps to 14 confirmed cases\\n\\n20 hours ago\\n\\nWeather News"}, {\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/weather-forecast/347625\', \'content\': "# Los Angeles, CA\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Today\\n\\n## Today\'s Weather\\n\\nTue, Jul 7\\n\\nSome low clouds early, then mostly sunny\\nHi: 85°\\n\\nTonight: Clear\\nLo: 63°\\n\\n## Current Weather\\n\\n3:35 AM\\n\\n## Looking Ahead\\n\\nMostly cloudy this weekend\\n\\n## Los Angeles Weather Radar\\n\\nLos Angeles Weather Radar\\n\\n## Hourly Weather\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\nrain drop\\n\\n## 10-Day Weather Forecast\\n\\nToday\\n\\n7/7 [...] rain drop\\n\\n## 10-Day Weather Forecast\\n\\nToday\\n\\n7/7\\n\\nPartly sunny\\n\\nNight: Clear\\n\\nWed\\n\\n7/8\\n\\nMostly sunny\\n\\nClear\\n\\nThu\\n\\n7/9\\n\\nPlenty of sun\\n\\nClear to partly cloudy\\n\\nFri\\n\\n7/10\\n\\nMostly sunny\\n\\nMainly clear\\n\\nSat\\n\\n7/11\\n\\nMostly cloudy\\n\\nPartly cloudy\\n\\nSun\\n\\n7/12\\n\\nCloudy\\n\\nA shower early; partly cloudy\\n\\nMon\\n\\n7/13\\n\\nPlenty of sunshine\\n\\nClear\\n\\n ...
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}]), ToolMessage(content='[{\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/july-weather/347625\', \'content\': "### Winter Center\\n\\n## Monthly\\n\\n## July\\n\\n## 2026\\n\\n## 10-Day\\n\\nPartly sunny\\nMostly sunny\\nPlenty of sun\\nMostly sunny\\nMostly cloudy\\nCloudy\\nPlenty of sunshine\\nPlenty of sunlight\\nSunny and warm\\nSunny and warm\\nWarm with sunshine\\nMostly sunny and warm\\nPlenty of sun\\nPlenty of sunshine\\nMostly sunny\\nMostly sunny\\nMostly sunny\\nIncreasing cloudiness\\nMostly cloudy and warm\\nDecreasing clouds\\nMostly sunny\\nPlenty of sun\\nMostly sunny\\nMostly cloudy\\nTimes of clouds and sun\\nSunny to partly cloudy\\n\\n## Temperature Graph\\n\\n## July Weather in Los Angeles\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### August 2026\\n\\n### September 2026\\n\\n### October 2026\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News\\n\\n### Video\\n\\n### Winter Center\\n\\nTop Stories\\n\\nSevere Weather [...] # Los Angeles, CA\\n\\nLos Angeles\\n\\nCalifornia\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Monthly\\n\\n## July\\n\\n## 2026\\n\\n## 10-Day [...] ### Video\\n\\n### Winter Center\\n\\nTop Stories\\n\\nSevere Weather\\n\\nStorms, downpours to persist this week across central, eastern US\\n\\n1 hour ago\\n\\nHurricane\\n\\nAtlantic hurricane season off to a slow start as El Niño strengthens\\n\\n1 hour ago\\n\\nSevere Weather\\n\\nStorms, heat and floods disrupt America’s 250th birthday celebrations\\n\\n15 hours ago\\n\\nWeather Forecasts\\n\\nExtreme heat to shift west into mid-July prior to return of monsoon\\n\\n1 hour ago\\n\\nLive: World Cup 2026 weather updates\\n\\nLATEST ENTRY\\n\\nStorms delay Mexico vs. England showdown in Mexico City\\n\\n20 hours ago\\n\\nFeatured Stories\\n\\nWeather News\\n\\nTexas Hill Country marks 1 year since deadly July 4 flood\\n\\n3 days ago\\n\\nHealth\\n\\nNYC Legionnaires\' disease outbreak jumps to 14 confirmed cases\\n\\n20 hours ago\\n\\nWeather News"}, {\'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/weather-forecast/347625\', \'content\': "# Los Angeles, CA\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Today\\n\\n## Today\'s Weather\\n\\nTue, Jul 7\\n\\nSome low clou ...
# {'messages': [AIMessage(content='The current weather in Los Angeles is mostly sunny with a high of 85°F and a low of 63°F. The weather is expected to be mostly sunny in the coming days.', response_metadata={'token_usage': {'completion_tokens': 38, 'prompt_tokens': 1341, 'total_tokens': 1379, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-02cb7fbc-bc77-4aa8-a45d-4e864ac7044d-0')]}

# %% [markdown]
# ## Add message to a state at a given time

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}, next=('action',), config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-2c40-6a2e-8001-b31a069924b2'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'llm': {'messages': [AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}])]}}}, created_at='2026-07-07T10:35:02.322620+00:00', parent_config={'configurable': {'thread_id': '3', 'thread_ts': '1f179ef8-2ba7-6629-8000-71e36c7636c2'}})

# %%
_id = to_replay.values['messages'][-1].tool_calls[0]['id']

# %%
state_update = {"messages": [ToolMessage(
    tool_call_id=_id,
    name="tavily_search_results_json",
    content="54 degree celcius",
)]}

# %%
branch_and_add = abot.graph.update_state(
    to_replay.config, 
    state_update, 
    as_node="action")

# %%
for event in abot.graph.stream(None, branch_and_add):
    for k, v in event.items():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', id='b234b5fd-b996-4843-b22e-df094469e684'), AIMessage(content='', additional_kwargs={'tool_calls': [{'function': {'arguments': '{"query":"weather in Los Angeles"}', 'name': 'tavily_search_results_json'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc', 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'logprobs': None, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'token_usage': {'completion_tokens': 22, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens': 152, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'total_tokens': 174}}, id='run-5b757f8e-f117-47fa-b17f-5621fb624a1e-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_6ED1ZQ8nrjYIOY14yqInLPZc'}]), ToolMessage(content='54 degree celcius', name='tavily_search_results_json', id='f5e10ea7-fe4c-4d3f-b26c-96c678daf1b7', tool_call_id='call_6ED1ZQ8nrjYIOY14yqInLPZc'), AIMessage(content='The current weather in Los Angeles is 54 degrees Celsius.', response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 190, 'total_tokens': 203, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-f389a9cb-4a7a-4bbf-adb3-e338c691e8a1-0')]}
# {'messages': [AIMessage(content='The current weather in Los Angeles is 54 degrees Celsius.', response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 190, 'total_tokens': 203, 'prompt_tokens_details': {'cached_tokens': 0, 'audio_tokens': 0}, 'completion_tokens_details': {'reasoning_tokens': 0, 'audio_tokens': 0, 'accepted_prediction_tokens': 0, 'rejected_prediction_tokens': 0}}, 'model_name': 'gpt-3.5-turbo', 'system_fingerprint': None, 'finish_reason': 'stop', 'logprobs': None}, id='run-f389a9cb-4a7a-4bbf-adb3-e338c691e8a1-0')]}

# %% [markdown]
# # Extra Practice

# %% [markdown]
# ## Build a small graph
# This is a small simple graph you can tinker with if you want more insight into controlling state memory.

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langgraph.checkpoint.sqlite import SqliteSaver

# %% [markdown]
# Define a simple 2 node graph with the following state:
# -`lnode`: last node
# -`scratch`: a scratchpad location
# -`count` : a counter that is incremented each step

# %%
class AgentState(TypedDict):
    lnode: str
    scratch: str
    count: Annotated[int, operator.add]

# %%
def node1(state: AgentState):
    print(f"node1, count:{state['count']}")
    return {"lnode": "node_1",
            "count": 1,
           }
def node2(state: AgentState):
    print(f"node2, count:{state['count']}")
    return {"lnode": "node_2",
            "count": 1,
           }

# %% [markdown]
# The graph goes N1->N2->N1... but breaks after count reaches 3.

# %%
def should_continue(state):
    return state["count"] < 3

# %%
builder = StateGraph(AgentState)
builder.add_node("Node1", node1)
builder.add_node("Node2", node2)

builder.add_edge("Node1", "Node2")
builder.add_conditional_edges("Node2", 
                              should_continue, 
                              {True: "Node1", False: END})
builder.set_entry_point("Node1")

# %%
memory = SqliteSaver.from_conn_string(":memory:")
graph = builder.compile(checkpointer=memory)

# %% [markdown]
# ### Run it!
# Now, set the thread and run!

# %%
thread = {"configurable": {"thread_id": str(1)}}
graph.invoke({"count":0, "scratch":"hi"},thread)
# Out:
# node1, count:0
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %% [markdown]
# ### Look at current state

# %% [markdown]
# Get the current state. Note the `values` which are the AgentState. Note the `config` and the `thread_ts`. You will be using those to refer to snapshots below.

# %%
graph.get_state(thread)
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f697-6a86-8004-321a9479e255'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-07-07T10:36:44.070137+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f694-6d12-8003-312552e7025b'}})

# %% [markdown]
# View all the statesnapshots in memory. You can use the displayed `count` agentstate variable to help track what you see. Notice the most recent snapshots are returned by the iterator first. Also note that there is a handy `step` variable in the metadata that counts the number of steps in the graph execution. This is a bit detailed - but you can also notice that the *parent_config* is the *config* of the previous node. At initial startup, additional states are inserted into memory to create a parent. This is something to check when you branch or *time travel* below.

# %% [markdown]
# ### Look at state history

# %%
for state in graph.get_state_history(thread):
    print(state, "\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f697-6a86-8004-321a9479e255'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-07-07T10:36:44.070137+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f694-6d12-8003-312552e7025b'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f694-6d12-8003-312552e7025b'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-07-07T10:36:44.068976+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f692-6369-8002-8d5a656b6fd3'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f692-6369-8002-8d5a656b6fd3'}}, metadata={'source': 'loop', 'step': 2, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-07-07T10:36:44.067902+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f68d-6cc3-8001-1bf244a87565'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f68d-6cc3-8001-1bf244a87565'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-07-07T10:36:44.066101+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f687-6a9a-8000-6cdd7c2f360c'}})
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f687-6a9a-8000-6cdd7c2f360c'}}, metadata={'source': 'loop', 'step': 0, 'writes': None}, created_at='2026-07-07T10:36:44.063588+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f684-6028-bfff-a24f0e5ea1af'}})
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f684-6028-bfff-a24f0e5ea1af'}}, metadata={'source': 'input', 'step': -1, 'writes': {'count': 0, 'scratch': 'hi'}}, created_at='2026-07-07T10:36:44.062090+00:00', parent_config=None)

# %% [markdown]
# Store just the `config` into an list. Note the sequence of counts on the right. `get_state_history` returns the most recent snapshots first.

# %%
states = []
for state in graph.get_state_history(thread):
    states.append(state.config)
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f697-6a86-8004-321a9479e255'}} 4
# {'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f694-6d12-8003-312552e7025b'}} 3
# {'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f692-6369-8002-8d5a656b6fd3'}} 2
# {'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f68d-6cc3-8001-1bf244a87565'}} 1
# {'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f687-6a9a-8000-6cdd7c2f360c'}} 0
# {'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f684-6028-bfff-a24f0e5ea1af'}} 0

# %% [markdown]
# Grab an early state.

# %%
states[-3]
# Out:
# {'configurable': {'thread_id': '1',
#   'thread_ts': '1f179efb-f68d-6cc3-8001-1bf244a87565'}}

# %% [markdown]
# This is the state after Node1 completed for the first time. Note `next` is `Node2`and `count` is 1.

# %%
graph.get_state(states[-3])
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f68d-6cc3-8001-1bf244a87565'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-07-07T10:36:44.066101+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f687-6a9a-8000-6cdd7c2f360c'}})

# %% [markdown]
# ### Go Back in Time
# Use that state in `invoke` to go back in time. Notice it uses states[-3] as *current_state* and continues to node2,

# %%
graph.invoke(None, states[-3])
# Out:
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %% [markdown]
# Notice the new states are now in state history. Notice the counts on the far right.

# %%
thread = {"configurable": {"thread_id": str(1)}}
for state in graph.get_state_history(thread):
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '1', 'thread_ts': '1f179efc-9a54-68bb-8004-d21ed6e42140'}} 4
# {'configurable': {'thread_id': '1', 'thread_ts': '1f179efc-9a51-6419-8003-e25a019a1e68'}} 3
# {'configurable': {'thread_id': '1', 'thread_ts': '1f179efc-9a4e-6aaf-8002-02856d264364'}} 2
# {'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f697-6a86-8004-321a9479e255'}} 4
# {'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f694-6d12-8003-312552e7025b'}} 3
# {'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f692-6369-8002-8d5a656b6fd3'}} 2
# {'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f68d-6cc3-8001-1bf244a87565'}} 1
# {'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f687-6a9a-8000-6cdd7c2f360c'}} 0
# {'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f684-6028-bfff-a24f0e5ea1af'}} 0

# %% [markdown]
# You can see the details below. Lots of text, but try to find the node that start the new branch. Notice the parent *config* is not the previous entry in the stack, but is the entry from state[-3].

# %%
thread = {"configurable": {"thread_id": str(1)}}
for state in graph.get_state_history(thread):
    print(state,"\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efc-9a54-68bb-8004-d21ed6e42140'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-07-07T10:37:01.239306+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efc-9a51-6419-8003-e25a019a1e68'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efc-9a51-6419-8003-e25a019a1e68'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-07-07T10:37:01.237958+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efc-9a4e-6aaf-8002-02856d264364'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efc-9a4e-6aaf-8002-02856d264364'}}, metadata={'source': 'loop', 'step': 2, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-07-07T10:37:01.236893+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f68d-6cc3-8001-1bf244a87565'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f697-6a86-8004-321a9479e255'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-07-07T10:36:44.070137+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f694-6d12-8003-312552e7025b'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f694-6d12-8003-312552e7025b'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-07-07T10:36:44.068976+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f692-6369-8002-8d5a656b6fd3'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f692-6369-8002-8d5a656b6fd3'}}, metadata={'source': 'loop', 'step': 2, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-07-07T10:36:44.067902+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f68d-6cc3-8001-1bf244a87565'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f68d-6cc3-8001-1bf244a87565'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-07-07T10:36:44.066101+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f687-6a9a-8000-6cdd7c2f360c'}})
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f687-6a9a-8000-6cdd7c2f360c'}}, metadata={'source': 'loop', 'step': 0, 'writes': None}, created_at='2026-07-07T10:36:44.063588+00:00', parent_config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f684-6028-bfff-a24f0e5ea1af'}})
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'thread_ts': '1f179efb-f684-6028-bfff-a24f0e5ea1af'}}, metadata={'source': 'input', 'step': -1, 'writes': {'count': 0, 'scratch': 'hi'}}, created_at='2026-07-07T10:36:44.062090+00:00', parent_config=None)

# %% [markdown]
# ### Modify State
# Let's start by starting a fresh thread and running to clean out history.

# %%
thread2 = {"configurable": {"thread_id": str(2)}}
graph.invoke({"count":0, "scratch":"hi"},thread2)
# Out:
# node1, count:0
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %%
from IPython.display import Image

Image(graph.get_graph().draw_png())

# %%
states2 = []
for state in graph.get_state_history(thread2):
    states2.append(state.config)
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc98-6836-8004-3e7ff1b67dd9'}} 4
# {'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc95-6ae2-8003-39c300384834'}} 3
# {'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc92-6d48-8002-897aa0908ba1'}} 2
# {'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc8f-69e7-8001-e5c16adda0b1'}} 1
# {'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc8a-629c-8000-b6c299ccb2a4'}} 0
# {'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc87-6819-bfff-67f456d2f089'}} 0

# %% [markdown]
# Start by grabbing a state.

# %%
save_state = graph.get_state(states2[-3])
save_state
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc8f-69e7-8001-e5c16adda0b1'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-07-07T10:37:06.506375+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc8a-629c-8000-b6c299ccb2a4'}})

# %% [markdown]
# Now modify the values. One subtle item to note: Recall when agent state was defined, `count` used `operator.add` to indicate that values are *added* to the current value. Here, `-3` will be added to the current count value rather than replace it.

# %%
save_state.values["count"] = -3
save_state.values["scratch"] = "hello"
save_state
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc8f-69e7-8001-e5c16adda0b1'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-07-07T10:37:06.506375+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc8a-629c-8000-b6c299ccb2a4'}})

# %% [markdown]
# Now update the state. This creates a new entry at the *top*, or *latest* entry in memory. This will become the current state.

# %%
graph.update_state(thread2,save_state.values)
# Out:
# {'configurable': {'thread_id': '2',
#   'thread_ts': '1f179efd-1ade-61d5-8005-bc3aecca23e6'}}

# %% [markdown]
# Current state is at the top. You can match the `thread_ts`.
# Notice the `parent_config`, `thread_ts` of the new node - it is the previous node.

# %%
for i, state in enumerate(graph.get_state_history(thread2)):
    if i >= 3:  #print latest 3
        break
    print(state, '\n')
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-1ade-61d5-8005-bc3aecca23e6'}}, metadata={'source': 'update', 'step': 5, 'writes': {'Node2': {'count': -3, 'lnode': 'node_1', 'scratch': 'hello'}}}, created_at='2026-07-07T10:37:14.717427+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc98-6836-8004-3e7ff1b67dd9'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc98-6836-8004-3e7ff1b67dd9'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-07-07T10:37:06.510024+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc95-6ae2-8003-39c300384834'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc95-6ae2-8003-39c300384834'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-07-07T10:37:06.508861+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc92-6d48-8002-897aa0908ba1'}})

# %% [markdown]
# ### Try again with `as_node`
# When writing using `update_state()`, you want to define to the graph logic which node should be assumed as the writer. What this does is allow th graph logic to find the node on the graph. After writing the values, the `next()` value is computed by travesing the graph using the new state. In this case, the state we have was written by `Node1`. The graph can then compute the next state as being `Node2`. Note that in some graphs, this may involve going through conditional edges!  Let's try this out.

# %%
graph.update_state(thread2,save_state.values, as_node="Node1")
# Out:
# {'configurable': {'thread_id': '2',
#   'thread_ts': '1f179efd-665c-6d82-8006-465caf637ad7'}}

# %%
for i, state in enumerate(graph.get_state_history(thread2)):
    if i >= 3:  #print latest 3
        break
    print(state, '\n')
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-665c-6d82-8006-465caf637ad7'}}, metadata={'source': 'update', 'step': 6, 'writes': {'Node1': {'count': -3, 'lnode': 'node_1', 'scratch': 'hello'}}}, created_at='2026-07-07T10:37:22.633642+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-1ade-61d5-8005-bc3aecca23e6'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-1ade-61d5-8005-bc3aecca23e6'}}, metadata={'source': 'update', 'step': 5, 'writes': {'Node2': {'count': -3, 'lnode': 'node_1', 'scratch': 'hello'}}}, created_at='2026-07-07T10:37:14.717427+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc98-6836-8004-3e7ff1b67dd9'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc98-6836-8004-3e7ff1b67dd9'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-07-07T10:37:06.510024+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc95-6ae2-8003-39c300384834'}})

# %% [markdown]
# `invoke` will run from the current state if not given a particular `thread_ts`. This is now the entry that was just added.

# %%
graph.invoke(None,thread2)
# Out:
# node2, count:-2
# node1, count:-1
# node2, count:0
# node1, count:1
# node2, count:2
# {'lnode': 'node_2', 'scratch': 'hello', 'count': 3}

# %% [markdown]
# Print out the state history, notice the `scratch` value change on the latest entries.

# %%
for state in graph.get_state_history(thread2):
    print(state,"\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 3}, next=(), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-7ee2-6922-800b-7218ce083bc8'}}, metadata={'source': 'loop', 'step': 11, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-07-07T10:37:25.205000+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-7ede-682d-800a-90183fdff0c7'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-7ede-682d-800a-90183fdff0c7'}}, metadata={'source': 'loop', 'step': 10, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-07-07T10:37:25.203340+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-7edb-6cf0-8009-371e6151c9b3'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-7edb-6cf0-8009-371e6151c9b3'}}, metadata={'source': 'loop', 'step': 9, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-07-07T10:37:25.202234+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-7ed7-636b-8008-60b0546fa01b'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 0}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-7ed7-636b-8008-60b0546fa01b'}}, metadata={'source': 'loop', 'step': 8, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-07-07T10:37:25.200349+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-7ed3-673b-8007-8f18b38221e6'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': -1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-7ed3-673b-8007-8f18b38221e6'}}, metadata={'source': 'loop', 'step': 7, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-07-07T10:37:25.198814+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-665c-6d82-8006-465caf637ad7'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-665c-6d82-8006-465caf637ad7'}}, metadata={'source': 'update', 'step': 6, 'writes': {'Node1': {'count': -3, 'lnode': 'node_1', 'scratch': 'hello'}}}, created_at='2026-07-07T10:37:22.633642+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-1ade-61d5-8005-bc3aecca23e6'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efd-1ade-61d5-8005-bc3aecca23e6'}}, metadata={'source': 'update', 'step': 5, 'writes': {'Node2': {'count': -3, 'lnode': 'node_1', 'scratch': 'hello'}}}, created_at='2026-07-07T10:37:14.717427+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc98-6836-8004-3e7ff1b67dd9'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc98-6836-8004-3e7ff1b67dd9'}}, metadata={'source': 'loop', 'step': 4, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-07-07T10:37:06.510024+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc95-6ae2-8003-39c300384834'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc95-6ae2-8003-39c300384834'}}, metadata={'source': 'loop', 'step': 3, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-07-07T10:37:06.508861+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc92-6d48-8002-897aa0908ba1'}})
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc92-6d48-8002-897aa0908ba1'}}, metadata={'source': 'loop', 'step': 2, 'writes': {'Node2': {'count': 1, 'lnode': 'node_2'}}}, created_at='2026-07-07T10:37:06.507684+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc8f-69e7-8001-e5c16adda0b1'}})
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc8f-69e7-8001-e5c16adda0b1'}}, metadata={'source': 'loop', 'step': 1, 'writes': {'Node1': {'count': 1, 'lnode': 'node_1'}}}, created_at='2026-07-07T10:37:06.506375+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc8a-629c-8000-b6c299ccb2a4'}})
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc8a-629c-8000-b6c299ccb2a4'}}, metadata={'source': 'loop', 'step': 0, 'writes': None}, created_at='2026-07-07T10:37:06.504146+00:00', parent_config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc87-6819-bfff-67f456d2f089'}})
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '2', 'thread_ts': '1f179efc-cc87-6819-bfff-67f456d2f089'}}, metadata={'source': 'input', 'step': -1, 'writes': {'count': 0, 'scratch': 'hi'}}, created_at='2026-07-07T10:37:06.503057+00:00', parent_config=None)

# %% [markdown]
# Continue to experiment!
